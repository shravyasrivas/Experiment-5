# %% [markdown]
# shravya srivastava 25070123106
# exp 5:
# AIM: Study of dictionaries in python.

# %%
 #creating dictionary
dict1={
     "name":"Shravya",0: 25070123107
 }
 #name of key can be a number
# dictionary contains two elemtens key and element
print(dict1)
#printing only name
print(dict1[0])
# Out:
# {'name': 'Shravya', 0: 25070123107}
# 25070123107

# %%
#Doesnt allow dupplicates , it doesnt allow overwriting
dict2={
    "name":"shravya",
    "name":"srivastava",
    "prn":25070123106,
    "cgpa":8,
    "cgpa":9
}
print(dict2)
# Out:
# {'name': 'srivastava', 'prn': 25070123106, 'cgpa': 9}

# %%
# Length of key value pairs
len(dict2)
# Out:
# 3

# %%
#Finding type
print(type(dict2))
# Out:
# <class 'dict'>

# %%
# Data is saved in pairs in dictionary, its mutable
#Changing/Adding key:Vale in Dictionary
dict2={
    "name":"shravya",
    "name":"srivastava",
    "prn":25070123106,
    "cgpa":8,
    "cgpa":9
}
dict2["branch"]="entc"
x=dict2.keys() #we used ys instead of value
print(dict2)
#Method 2:
dict2.update({"batch":"b"})
print(dict2)
#Printing only values
x=dict2.values()
print(x)
# Out:
# {'name': 'srivastava', 'prn': 25070123106, 'cgpa': 9, 'branch': 'entc'}
# {'name': 'srivastava', 'prn': 25070123106, 'cgpa': 9, 'branch': 'entc', 'batch': 'b'}
# dict_values(['srivastava', 25070123106, 9, 'entc', 'b'])

# %%
#Printing Selective Values
dict2={
    "name":"shravya",
    "name":"srivastava",
    "prn":25070123106,
    "cgpa":8,
    "cgpa":9
}
x=dict2.get("name")
print("Name:",x)
#Method 2
print("prn:",dict2["prn"])
# Out:
# Name: srivastava
# prn: 25070123106

# %%
#Removing of values
dict2={
    "name":"shravya",
    "name":"srivastava",
    "prn":25070123106,
    "cgpa":8,
    "cgpa":9
}
dict2.pop("cgpa")
print(dict2)
# Out:
# {'name': 'srivastava', 'prn': 25070123106}

# %%
''' Problem Statement 1:
A dictionary stores product names and their prices, write a  python program to update the price of a given product,'''
dict3={
    "rice":55,
    "flour":77,
    "wheat":60
}
dict3["rice"]=59
print("updated dictionary:",dict3)
# Out:
# updated dictionary: {'rice': 59, 'flour': 77, 'wheat': 60}

# %%
'''Problem Statement 2: A dictionary stores names and marks.
 Write a python program to search for a student's marks using the name entered by the user.
 If the student is not found,display a suitable message.'''
marks={
     "rohit":5,
     "ronit":3,
     "mehra":6
 }
print("ronit marks:",marks.get("ronit"))
print("vishwesh marks:",marks.get("vishwesh"))

#Method 2:
name=input("enter name:")
print(marks.get(name,"student not found"))
# Out:
# ronit marks: 3
# vishwesh marks: None
# enter name:ruchika
# student not found

# %%
'''Problem Statement 3:
A dictionary stores username and password.
Write a Python program to validate user login'''
id={"shravya12":"1246@2", #doesnt take numeriacal value, is not able to get it if pasword is number not string
    "ruchika07":"Bhat@06"
}
username=input("enter username:")
password=input("ente password:")
if id.get(username)==(password):
  print("login successfull")
else:
  print("login failed")
# Out:
# enter username:ruchika07
# ente password:Bhat@06
# login successfull

# %%
'''Prroblem Statement 4:
A dictioary stores student names and marks.
Write  python program to find the tudnt who scores the highest marks'''
name={
    "Shravya":88,
    "Vishwesh":81,
    "Ruchika":88
}
topper=max(name,key=name.get)
print("Topper:",topper)
#Limitation of this program :can only run for different marks
# Out:
# Topper: Shravya
